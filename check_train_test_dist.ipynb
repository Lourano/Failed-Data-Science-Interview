# %% [markdown]
# # Third Part of Work
#
# In this part I decided to ckeck train and test distibutions.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %matplotlib inline

# %%
train = pd.read_csv('cleaned_train_df.csv')
test = pd.read_csv('cleaned_test_df.csv')
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18326 entries, 0 to 18325
# Data columns (total 12 columns):
# Date              18326 non-null object
# Bid_Price         18326 non-null float64
# Bid_Shares        18326 non-null int64
# Ask_Price         18326 non-null float64
# Ask_Shares        18326 non-null int64
# FeaturePrice1     18326 non-null float64
# FeaturePrice2     18326 non-null float64
# FeaturePrice3     18326 non-null float64
# FeaturePrice4     18326 non-null float64
# FeatureShares1    18326 non-null int64
# FeatureShares2    18326 non-null int64
# TargetPrice       18326 non-null float64
# dtypes: float64(7), int64(4), object(1)
# memory usage: 1.7+ MB

# %%
sns.distplot(train.Bid_Price)
sns.distplot(test.Bid_Price)
plt.legend(['train', 'test']) #looks good

# %%
sns.distplot(train.Bid_Shares)
sns.distplot(test.Bid_Shares)
plt.legend(['train', 'test']) # looks a little bit terrible, but out of ignorance, of the values, of this feature,
                              # I decided to leave everything as it is

# %%
train.Bid_Shares.mean()
# Out:
# 3222.870730110226

# %%
test.Bid_Shares.mean()
# Out:
# 7739.508589276418

# %%
sns.distplot(train.Ask_Price)
sns.distplot(test.Ask_Price)
plt.legend(['train', 'test']) #good

# %%
sns.distplot(train.Ask_Shares)
sns.distplot(test.Ask_Shares)
plt.legend(['train', 'test']) # +- good

# %%
train.Ask_Shares.describe()
# Out:
# count     18326.000000
# mean       2751.391793
# std       16396.574881
# min           0.000000
# 25%         100.000000
# 50%         200.000000
# 75%         929.750000
# max      633852.000000
# Name: Ask_Shares, dtype: float64

# %%
test.Ask_Shares.describe()
# Out:
# count      3842.000000
# mean       2608.901874
# std       13213.021597
# min           0.000000
# 25%         100.000000
# 50%         200.000000
# 75%        1000.000000
# max      339456.000000
# Name: Ask_Shares, dtype: float64

# %%
sns.distplot(train.FeaturePrice1)
sns.distplot(test.FeaturePrice1)
plt.legend(['train', 'test']) #good

# %%
sns.distplot(train.FeaturePrice2)
sns.distplot(test.FeaturePrice2)
plt.legend(['train', 'test']) # good

# %%
sns.distplot(train.FeaturePrice3)
sns.distplot(test.FeaturePrice3)
plt.legend(['train', 'test']) #good

# %%
sns.distplot(train.FeaturePrice4)
sns.distplot(test.FeaturePrice4)
plt.legend(['train', 'test']) #good

# %%
sns.distplot(train.FeatureShares1)
sns.distplot(test.FeatureShares1)
plt.legend(['train', 'test']) # +- good

# %%
train.FeatureShares1.describe()
# Out:
# count    1.832600e+04
# mean     2.733409e+04
# std      8.666960e+04
# min      0.000000e+00
# 25%      9.322500e+02
# 50%      5.213000e+03
# 75%      1.897000e+04
# max      2.184752e+06
# Name: FeatureShares1, dtype: float64

# %%
test.FeatureShares1.describe()
# Out:
# count    3.842000e+03
# mean     2.960325e+04
# std      1.591276e+05
# min      0.000000e+00
# 25%      5.992500e+02
# 50%      4.399500e+03
# 75%      1.829375e+04
# max      7.335035e+06
# Name: FeatureShares1, dtype: float64
