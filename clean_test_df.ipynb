# %% [markdown]
# # Second part of Work
#
# I decided to do the same things as from the training set, but instead of deleting the lines, I replaced them with vector averages

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %matplotlib inline

# %%
df = pd.read_csv('test.csv')
df.Date = pd.to_datetime(df.Date)
df = df.sort_values(by = 'Date')
df
# Out:
#            Date  Bid_Price  Bid_Shares  Ask_Price  Ask_Shares  FeaturePrice1  \
# 0    2016-09-15       3.05         200       4.63         100         3.4500
# 100  2016-09-15    1429.00          22    1431.22           6      1431.2200
# 101  2016-09-15       0.01         200      21.00         100        20.9600
# 102  2016-09-15       0.22         100       0.24        2345         0.2201
# 103  2016-09-15     203.00          25     209.86          30       203.0000
# ...         ...        ...         ...        ...         ...            ...
# 3805 2016-10-14       0.08        1533       0.11           1         0.1187
# 3806 2016-10-14      38.47         230      38.95         770        38.9500
# 3807 2016-10-14      30.34         300      31.40         200        31.4000
# 3800 2016-10-14      17.09        7100      17.13        7100        17.0900
# 3906 2016-10-14      22.33          50      22.40          20        22.5900
#
# ...

# %%
df.describe()
# Out:
#          Bid_Price    Bid_Shares      Ask_Price     Ask_Shares  FeaturePrice1  \
# count  3907.000000  3.907000e+03    3907.000000    3907.000000    3907.000000
# mean     46.508999  7.627535e+03    2761.674919    2567.980804     124.327717
# std     111.427915  1.151931e+05   22114.663216   13106.434021    3577.716624
# min       0.000000  0.000000e+00       0.000000       0.000000       0.008000
# 25%       4.610000  1.000000e+02       5.685000     100.000000       5.490000
# 50%      18.000000  2.000000e+02      21.590000     200.000000      19.430000
# 75%      48.860000  1.000000e+03      53.120000    1000.000000      49.890000
# max    1488.000000  3.584800e+06  199999.990000  339456.000000  199999.990000
#
#        FeaturePrice2  FeaturePrice3  FeaturePrice4  FeatureShares1  \
# count    3907.000000    3907.000000    3907.000000    3.907000e+03
# mean      124.327983     336.918083      47.644975    2.912405e+04
# ...

# %%
sns.boxplot(df.Ask_Price)

# %%
indexes = df[df.Ask_Price > 50000].index

for i in indexes:
    df.at[i, 'Ask_Price'] = np.mean(df.Ask_Price)

# %%
df.describe()
# Out:
#          Bid_Price    Bid_Shares    Ask_Price     Ask_Shares  FeaturePrice1  \
# count  3907.000000  3.907000e+03  3907.000000    3907.000000    3907.000000
# mean     46.508999  7.627535e+03    72.111713    2567.980804     124.327717
# std     111.427915  1.151931e+05   234.956837   13106.434021    3577.716624
# min       0.000000  0.000000e+00     0.000000       0.000000       0.008000
# 25%       4.610000  1.000000e+02     5.685000     100.000000       5.490000
# 50%      18.000000  2.000000e+02    21.590000     200.000000      19.430000
# 75%      48.860000  1.000000e+03    53.120000    1000.000000      49.890000
# max    1488.000000  3.584800e+06  2761.674919  339456.000000  199999.990000
#
#        FeaturePrice2  FeaturePrice3  FeaturePrice4  FeatureShares1  \
# count    3907.000000    3907.000000    3907.000000    3.907000e+03
# mean      124.327983     336.918083      47.644975    2.912405e+04
# std      3577.716633    7436.353348     112.324846    1.578418e+05
# ...

# %%
sns.boxplot(df.FeaturePrice1)

# %%
indexes = df[df.FeaturePrice1 > 50000].index

for i in indexes:
    df.at[i, 'FeaturePrice1'] = np.mean(df.FeaturePrice1)

# %%
df.describe()
# Out:
#          Bid_Price    Bid_Shares    Ask_Price     Ask_Shares  FeaturePrice1  \
# count  3907.000000  3.907000e+03  3907.000000    3907.000000    3907.000000
# mean     46.508999  7.627535e+03    72.111713    2567.980804      47.593012
# std     111.427915  1.151931e+05   234.956837   13106.434021     111.530279
# min       0.000000  0.000000e+00     0.000000       0.000000       0.008000
# 25%       4.610000  1.000000e+02     5.685000     100.000000       5.490000
# 50%      18.000000  2.000000e+02    21.590000     200.000000      19.430000
# 75%      48.860000  1.000000e+03    53.120000    1000.000000      49.890000
# max    1488.000000  3.584800e+06  2761.674919  339456.000000    1489.390000
#
#        FeaturePrice2  FeaturePrice3  FeaturePrice4  FeatureShares1  \
# count    3907.000000    3907.000000    3907.000000    3.907000e+03
# mean      124.327983     336.918083      47.644975    2.912405e+04
# std      3577.716633    7436.353348     112.324846    1.578418e+05
# ...

# %%
sns.boxplot(df.FeaturePrice3)

# %%
indexes = df[df.FeaturePrice1 > 50000].index

for i in indexes:
    df.at[i, 'FeaturePrice3'] = np.mean(df.FeaturePrice1)

# %%
df.describe()
# Out:
#          Bid_Price    Bid_Shares    Ask_Price     Ask_Shares  FeaturePrice1  \
# count  3907.000000  3.907000e+03  3907.000000    3907.000000    3907.000000
# mean     46.508999  7.627535e+03    72.111713    2567.980804      47.593012
# std     111.427915  1.151931e+05   234.956837   13106.434021     111.530279
# min       0.000000  0.000000e+00     0.000000       0.000000       0.008000
# 25%       4.610000  1.000000e+02     5.685000     100.000000       5.490000
# 50%      18.000000  2.000000e+02    21.590000     200.000000      19.430000
# 75%      48.860000  1.000000e+03    53.120000    1000.000000      49.890000
# max    1488.000000  3.584800e+06  2761.674919  339456.000000    1489.390000
#
#        FeaturePrice2  FeaturePrice3  FeaturePrice4  FeatureShares1  \
# count    3907.000000    3907.000000    3907.000000    3.907000e+03
# mean      124.327983     336.918083      47.644975    2.912405e+04
# std      3577.716633    7436.353348     112.324846    1.578418e+05
# ...

# %%
df.corr()
# Out:
#                 Bid_Price  Bid_Shares  Ask_Price  Ask_Shares  FeaturePrice1  \
# Bid_Price        1.000000   -0.024113   0.441718   -0.050413       0.998945
# Bid_Shares      -0.024113    1.000000  -0.011838    0.089715      -0.024714
# Ask_Price        0.441718   -0.011838   1.000000   -0.043973       0.447351
# Ask_Shares      -0.050413    0.089715  -0.043973    1.000000      -0.052070
# FeaturePrice1    0.998945   -0.024714   0.447351   -0.052070       1.000000
# FeaturePrice2    0.022302   -0.002154   0.049213   -0.005663       0.042654
# FeaturePrice3    0.003395   -0.002258   0.176419   -0.006966       0.009531
# FeaturePrice4    0.990001   -0.024583   0.442506   -0.051948       0.990700
# FeatureShares1   0.011015   -0.004486  -0.013746    0.025286       0.009529
# FeatureShares2   0.007419   -0.122892   0.005536   -0.074310       0.008159
#
#                 FeaturePrice2  FeaturePrice3  FeaturePrice4  FeatureShares1  \
# ...

# %%
df.to_csv('cleaned_test_df.csv', index = False)
